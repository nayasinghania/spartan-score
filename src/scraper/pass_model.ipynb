# %%
import pandas as pd

# %%
df = pd.read_csv("sjsu_rmp.csv")
df.head()

# %%
df["grade"].dropna()
df = df[
    ~df["grade"].isin(
        [
            "Not sure yet",
            "Rather not say",
            "Not_Sure_Yet",
            "Audit/No Grade",
            "Rather_Not_Say",
            "Pass",
            "Fail",
            "Audit/No_Grade",
        ]
    )
]
df["grade"].value_counts()
