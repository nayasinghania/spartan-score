# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("sjsu_rmp.csv")
df.head()
# Out:
#   professor_first_name professor_last_name    professor_department  \
# 0                 Eric             Crabill  Electrical Engineering
# 1                 Eric             Crabill  Electrical Engineering
# 2                 Eric             Crabill  Electrical Engineering
# 3                 Eric             Crabill  Electrical Engineering
# 4                 Eric             Crabill  Electrical Engineering
#
#    avg_difficulty  avg_rating  num_ratings  would_take_again_percent  \
# 0             2.8         4.9           14                     100.0
# 1             2.8         4.9           14                     100.0
# 2             2.8         4.9           14                     100.0
# 3             2.8         4.9           14                     100.0
# 4             2.8         4.9           14                     100.0
#
#                                              comment  difficulty_rating  \
# 0  Eric is one of the best professors I have ever...                  1
# 1  Great professor taught me a lot about microchi...                  4
# 2  Amazing Lectures, inspiring speeches, takes th...                  3
# 3  EE178 with Professor Crabill is a 100% practic...                  3
# 4  Crabill is a perfect example of how a great pr...                  2
#
#           grade  clarity_rating  \
# 0            A+               5
# 1             A               5
# 2             A               5
# 3  Not sure yet               5
# 4             A               4
#
#                                          rating_tags
# 0         Respected--Inspirational--Amazing lectures
# 1         Inspirational--Hilarious--Amazing lectures
# 2  Gives good feedback--Respected--Get ready to read
# 3        Gives good feedback--Clear grading criteria
# 4                                                NaN

# %%
df = df.drop(columns=["comment", "rating_tags"])
df = df.dropna()
df.head()
# Out:
#   professor_first_name professor_last_name    professor_department  \
# 0                 Eric             Crabill  Electrical Engineering
# 1                 Eric             Crabill  Electrical Engineering
# 2                 Eric             Crabill  Electrical Engineering
# 3                 Eric             Crabill  Electrical Engineering
# 4                 Eric             Crabill  Electrical Engineering
#
#    avg_difficulty  avg_rating  num_ratings  would_take_again_percent  \
# 0             2.8         4.9           14                     100.0
# 1             2.8         4.9           14                     100.0
# 2             2.8         4.9           14                     100.0
# 3             2.8         4.9           14                     100.0
# 4             2.8         4.9           14                     100.0
#
#    difficulty_rating         grade  clarity_rating
# 0                  1            A+               5
# 1                  4             A               5
# 2                  3             A               5
# 3                  3  Not sure yet               5
# 4                  2             A               4

# %%
order = {
    "A+": 0,
    "A": 1,
    "A-": 2,
    "B+": 3,
    "B": 4,
    "B-": 5,
    "C+": 6,
    "C": 7,
    "C-": 8,
    "D": 9,
    "F": 10,
}
df = df[
    ~df["grade"].isin(
        [
            "Not sure yet",
            "Rather not say",
            "Not_Sure_Yet",
            "Audit/No Grade",
            "Rather_Not_Say",
            "Pass",
            "Fail",
            "Audit/No_Grade",
        ]
    )
]
df["grade_encoded"] = df["grade"].map(order)
df = df.drop(columns=["grade"])
df.head()
# Out:
#   professor_first_name professor_last_name    professor_department  \
# 0                 Eric             Crabill  Electrical Engineering
# 1                 Eric             Crabill  Electrical Engineering
# 2                 Eric             Crabill  Electrical Engineering
# 4                 Eric             Crabill  Electrical Engineering
# 5                 Eric             Crabill  Electrical Engineering
#
#    avg_difficulty  avg_rating  num_ratings  would_take_again_percent  \
# 0             2.8         4.9           14                     100.0
# 1             2.8         4.9           14                     100.0
# 2             2.8         4.9           14                     100.0
# 4             2.8         4.9           14                     100.0
# 5             2.8         4.9           14                     100.0
#
#    difficulty_rating  clarity_rating  grade_encoded
# 0                  1               5            0.0
# 1                  4               5            1.0
# 2                  3               5            1.0
# 4                  2               4            1.0
# 5                  4               4            2.0

# %%
df["professor_name"] = df["professor_first_name"] + " " + df["professor_last_name"]
prof_counts = df["professor_name"].value_counts()
df["professor_name"] = df["professor_name"].where(
    prof_counts[df["professor_name"]] >= 10, "Other"
)
df = df.drop(columns=["professor_first_name", "professor_last_name"])
df = pd.get_dummies(df, columns=["professor_department", "professor_name"], dtype=int)

df.head()
# Out:
#    avg_difficulty  avg_rating  num_ratings  would_take_again_percent  \
# 0             2.8         4.9           14                     100.0
# 1             2.8         4.9           14                     100.0
# 2             2.8         4.9           14                     100.0
# 4             2.8         4.9           14                     100.0
# 5             2.8         4.9           14                     100.0
#
#    difficulty_rating  clarity_rating  grade_encoded  \
# 0                  1               5            0.0
# 1                  4               5            1.0
# 2                  3               5            1.0
# 4                  2               4            1.0
# 5                  4               4            2.0
#
#    professor_department_Accounting  professor_department_Accounting  Finance  \
# 0                                0                                         0
# 1                                0                                         0
# 2                                0                                         0
# 4                                0                                         0
# 5                                0                                         0
#
#    professor_department_Accounting & Finance  ...  \
# 0                                          0  ...
# 1                                          0  ...
# 2                                          0  ...
# 4                                          0  ...
# 5                                          0  ...
#
#    professor_department_Special Education  professor_department_Technology  \
# 0                                       0                                0
# 1                                       0                                0
# 2                                       0                                0
# 4                                       0                                0
# 5                                       0                                0
#
#    professor_department_Theater  professor_department_University Studies  \
# 0                             0                                        0
# 1                             0                                        0
# 2                             0                                        0
# 4                             0                                        0
# 5                             0                                        0
#
#    professor_department_Urban & Regional Planning  \
# 0                                               0
# 1                                               0
# 2                                               0
# 4                                               0
# 5                                               0
#
#    professor_department_Urban Planning  professor_department_Vietnamese  \
# 0                                    0                                0
# 1                                    0                                0
# 2                                    0                                0
# 4                                    0                                0
# 5                                    0                                0
#
#    professor_department_Women's Studies  professor_department_Writing  \
# 0                                     0                             0
# 1                                     0                             0
# 2                                     0                             0
# 4                                     0                             0
# 5                                     0                             0
#
#    professor_name_Other
# 0                     1
# 1                     1
# 2                     1
# 4                     1
# 5                     1
#
# [5 rows x 137 columns]

# %%
x = df.drop(columns=["difficulty_rating"])
y = df["difficulty_rating"]
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.1, random_state=42
)
rf_regressor = RandomForestRegressor(n_estimators=200, random_state=42)
rf_regressor.fit(x_train, y_train)
y_pred = rf_regressor.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")
# Out:
# Mean Squared Error: 0.8795136412748857
# R^2 Score: 0.4103585970796281
